# %%
import pandas as pd

pd.read_excel('CAORAN.xlsx')
# Out:
#     observation_date  CAORAN7POP  GDPALL06059  REALGDPALL06059     CANGSP  \
# 0               1970    1421.233          NaN              NaN        NaN
# 1               1971    1484.200          NaN              NaN        NaN
# 2               1972    1536.800          NaN              NaN        NaN
# 3               1973    1607.100          NaN              NaN        NaN
# 4               1974    1669.100          NaN              NaN        NaN
# 5               1975    1725.700          NaN              NaN        NaN
# 6               1976    1772.700          NaN              NaN        NaN
# 7               1977    1812.100          NaN              NaN        NaN
# 8               1978    1853.100          NaN              NaN        NaN
# 9               1979    1892.000          NaN              NaN        NaN
# 10              1980    1932.921          NaN              NaN        NaN
# 11              1981    2004.806          NaN              NaN        NaN
# ...
